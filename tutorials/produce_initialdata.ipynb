# %%
from nrtools.initialdata import *
import os

# %%
binary = {
    'bh_mass' : '8.0',
    'ns_mass' : '1.6', 
    'bh_chi_z':'0.0', 
    'binary_separation':'40',
    'eos'     : 'SLy'
}

# Prepare output for ID
outdir = './test_id'
try:
    os.mkdir(outdir)
except FileExistsError:
    print('Directory exists already: ',outdir)

# Create initial data

bhns_id = initialdata.Initial_Data(path=outdir,params=binary)
# Out:
# Directory exists already:  ./test_id
# Directory exists already:  ./test_id/SLy_BH_m8.0_s0.0--NS_m1.6_s0--d40
